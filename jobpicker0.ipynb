# %% [markdown]
# <a href="https://colab.research.google.com/github/fThAbhishek-Pandey/JobsTime-Job-Assistant/blob/main/jobpicker0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jobpicker Assistant
#
# *   fetch the html content of the webpage : request library
#
# *   Scrape the data to fetch the result : beautifulsoup

# %%
import requests as rq

html_text =  rq.get("https://www.timesjobs.com/candidate/job-search.html?searchName=recentSearches&from=submit&luceneResultSize=25&txtKeywords=0DQT0Software%20Developer0DQT0&cboWorkExp1=0&postWeek=60&searchType=personalizedSearch&actualTxtKeywords=0DQT0Software%20Developer0DQT0&searchBy=0&rdoOperator=OR&txtLocation=India&gadLink=0DQT0Software%20Developer0DQT0,%20India,%20Entry%20Level").text
print(html_text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
#
# 	<link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet">
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#        <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" rel="stylesheet" type="text/css" media="all"/>
#       	<script type="text/javascript" src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js"></script>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript">
#   </script>
# ...

# %% [markdown]
# # Finding Compnay Name

# %%
compnany_name= soup.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
print(compnany_name)
# Out:
# CEORRATECHNOLOGIESPRIVATELIMITED
# (MoreJobs)

# %% [markdown]
# #Finding skill

# %%
skills = soup.find("span",class_="srp-skills").text.replace(" ","").strip()
print(skills)
# Out:
# SoftwareDeveloper,softwareprogrammer,itexecutive

# %% [markdown]
# #Finding post date

# %%
date_posted= soup.find("span", class_="sim-posted").text.strip()
print(date_posted)
# Out:
# Posted a month ago

# %%
print(f'''
company Name : {compnany_name}
Skills Needed: {skills}
date posted  : {date_posted}
''')
# Out:
# company Name : CEORRATECHNOLOGIESPRIVATELIMITED
# (MoreJobs)
# Skills Needed: Software Developer  ,  software programmer  ,  it executive
# date posted  : Posted a month ago

# %% [markdown]
# #The above we find only one job , Now we move to find job List

# %%
jobs= soup.find_all("li",class_="clearfix job-bx wht-shd-bx")
print(jobs)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/software-developer-ceorra-technologies-private-limited-ahmedabad-0-to-3-yrs-jobid-oF36mqB0GyxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69814619','Software Developer  ,  software programmer  ,  it executive','Ahmedabad','0 - 3','IT Software : Software Products &amp; Services,  Marketing / Media Planning / MR / Comm. (Digital &amp; Offline)','1','' )" target="_blank">
# <strong class="blkclor">SOFTWARE</strong> <strong class="blkclor">DEVELOPER</strong></a> </h2>
# <h3 class="joblist-comp-name">
#     CEORRA TECHNOLOGIES PRIVATE LIMITED
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=YYD2TIC0jq66ZVj35Vka0g==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# ...

# %%
for job in jobs:
  compnany_name= job.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
  skill = job.find("span",class_="srp-skills").text.replace(" ","").strip()
  date_posted= job.find("span", class_="sim-posted").text.strip()
  print(f'''
  company Name : {compnany_name}
  Skills Needed: {skill}
  date posted  : {date_posted}
  ''')
# Out:
#   company Name : CEORRATECHNOLOGIESPRIVATELIMITED
# (MoreJobs)
#   Skills Needed: SoftwareDeveloper,softwareprogrammer,itexecutive
#   date posted  : Posted a month ago
#
#
#   company Name : CEORRATECHNOLOGIESPRIVATELIMITED
# (MoreJobs)
#   Skills Needed: softwaredeveloper
#   date posted  : Posted a month ago
#
#
#   company Name : CEORRATECHNOLOGIESPRIVATELIMITED
# (MoreJobs)
#   Skills Needed: softwaredeveloper
#   date posted  : Posted a month ago
#
#
#   company Name : AMARTECHNOLABSPVTLTD
# (MoreJobs)
#   Skills Needed: php,asp.net,meansstack,frontend,python,DigitalMarketing,BusinessDevelopment,webdeveloper,phpprogrammer,juniorprogrammer
#   date posted  : Posted few days ago
#
#
#   company Name : AMARTECHNOLABSPVTLTD
# (MoreJobs)
#   Skills Needed: php,Html,mysql,webdevloper,HTMLJavaScript,laravel,corephp,Css
#   date posted  : Posted 4 days ago
#
#
#   company Name : IDZDigital
#   Skills Needed: mobile,ios,SoftwareDeveloper
#   date posted  : Posted few days ago
#
#
# ...

# %% [markdown]
# custmuzing jobs

# %%
for job in jobs:
  date_posted= job.find("span", class_="sim-posted").text.strip()
  if "few" in date_posted: #custmize for recently
    compnany_name= job.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
    skill = job.find("span",class_="srp-skills").text.replace(" ","").strip()

    print(f'''
company Name : {compnany_name}
Skills Needed: {skill}
date posted  : {date_posted}
''')
# Out:
# company Name : AMARTECHNOLABSPVTLTD
# (MoreJobs)
# Skills Needed: php,asp.net,meansstack,frontend,python,DigitalMarketing,BusinessDevelopment,webdeveloper,phpprogrammer,juniorprogrammer
# date posted  : Posted few days ago
#
#
# company Name : IDZDigital
# Skills Needed: mobile,ios,SoftwareDeveloper
# date posted  : Posted few days ago
#
#
# company Name : CylsysSoftwareSolutionsPvt.Ltd.
# Skills Needed: html5,mobile,softwaredeveloper
# date posted  : Posted few days ago
#
#
# company Name : CytrionSoftwareSolutionsPvtLtd
# Skills Needed: c#,security,java,php,.net,softwaredeveloper
# date posted  : Posted few days ago
#
#
# company Name : InternetDesignZone
# Skills Needed: mobileappdevelopment,ios,Softwaredeveloper
# date posted  : Posted few days ago
#
#
# company Name : alliancerecruitmentagency
# Skills Needed: c#,softwaredesign,git,asp.net,oops,mvc,softwaredeveloper
# date posted  : Posted few days ago
#
#
# company Name : BUSISOLSOURCINGINDIAPVT.LTD
# ...

# %% [markdown]
# #Skillwise Custmizise

# %%
known_skill= input("please provide your skill sets in comma separated way ")
known_skill=known_skill.split(",")
print(known_skill)
# Out:
# please provide your skill sets in comma separated way java,html,ruby
# ['java', 'html', 'ruby']

# %%
print(known_skill)
for job in jobs:
  date_posted= job.find("span", class_="sim-posted").text.strip()
  skill = job.find("span",class_="srp-skills").text.replace(" ","").strip()
  print(skill)
  applicable =bool(set(known_skill) & set(skill))
  # print(type(applicable))
  print(applicable)
  if  applicable: #custmize according to your skill
    compnany_name= job.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
    print(f'''
company Name : {compnany_name}
Skills Needed: {skill}
date posted  : {date_posted}
''')
# Out:
# ['java', 'html', 'ruby']
# SoftwareDeveloper,softwareprogrammer,itexecutive
# False
# softwaredeveloper
# False
# softwaredeveloper
# False
# php,asp.net,meansstack,frontend,python,DigitalMarketing,BusinessDevelopment,webdeveloper,phpprogrammer,juniorprogrammer
# False
# php,Html,mysql,webdevloper,HTMLJavaScript,laravel,corephp,Css
# False
# mobile,ios,SoftwareDeveloper
# False
# html5,mobile,softwaredeveloper
# False
# c#,security,java,php,.net,softwaredeveloper
# False
# mobileappdevelopment,ios,Softwaredeveloper
# False
# spring,rest,java,telecomdomain,softwaredeveloper,soap,javadeveloper
# False
# c#,softwaredesign,git,asp.net,oops,mvc,softwaredeveloper
# False
# c#,html5,microsoftazure,asp.net,.net,mvc,softwaredeveloper
# False
# c#,datastructures,objectorientedprogramming,softwaredeveloper
# False
# c#,css,entityframework,ado.net,problemsolving,jquery,asp.net,.net,html,mvc,softwaredeveloper,ioc
# False
# ...

# %% [markdown]
# #Finding Apply Link

# %%
for job in jobs:
  date_posted= job.find("span", class_="sim-posted").text.strip()
  if "few" in date_posted: #custmize for recently
    compnany_name= job.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
    skill = job.find("span",class_="srp-skills").text.replace(" ","").strip()
    jd= job.header.h2.a['href']
    print(f'''
company Name : {compnany_name}
Skills Needed: {skill}
Apply Link   : {jd}
date posted  : {date_posted}
''')
# Out:
# company Name : AMARTECHNOLABSPVTLTD
# (MoreJobs)
# Skills Needed: php,asp.net,meansstack,frontend,python,DigitalMarketing,BusinessDevelopment,webdeveloper,phpprogrammer,juniorprogrammer
# Apply Link   : https://www.timesjobs.com/job-detail/internship-opportunity-for-software-developer-bca-diploma-be-excel-ptp-solutions-ahmedabad-0-to-1-yrs-jobid-VWLx7DZn6S9zpSvf__PLUS__uAgZw==&source=srp
# date posted  : Posted few days ago
#
#
# company Name : IDZDigital
# Skills Needed: mobile,ios,SoftwareDeveloper
# Apply Link   : https://www.timesjobs.com/job-detail/software-developer-idz-digital-mumbai-0-to-3-yrs-jobid-CuzZ7qwLdINzpSvf__PLUS__uAgZw==&source=srp
# date posted  : Posted few days ago
#
#
# company Name : CylsysSoftwareSolutionsPvt.Ltd.
# Skills Needed: html5,mobile,softwaredeveloper
# Apply Link   : https://www.timesjobs.com/job-detail/software-developer-cylsys-software-solutions-pvt-ltd-bhopal-0-to-2-yrs-jobid-iNbqmUEuazVzpSvf__PLUS__uAgZw==&source=srp
# ...

# %% [markdown]
# #Production Ready Code

# %%
import requests as rq
from bs4 import BeautifulSoup
import time
known_skill= input("please provide your skill sets in comma separated way ")
known_skill=known_skill.split(",")
def scrap_jobs():
    html_text =  rq.get("https://www.timesjobs.com/candidate/job-search.html?searchName=recentSearches&from=submit&luceneResultSize=25&txtKeywords=0DQT0Software%20Developer0DQT0&cboWorkExp1=0&postWeek=60&searchType=personalizedSearch&actualTxtKeywords=0DQT0Software%20Developer0DQT0&searchBy=0&rdoOperator=OR&txtLocation=India&gadLink=0DQT0Software%20Developer0DQT0,%20India,%20Entry%20Level").text

    soup = BeautifulSoup(html_text,'lxml')
    compnany_name= soup.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
    skills = soup.find("span",class_="srp-skills").text.replace(" ","").strip()
    jobs= soup.find_all("li",class_="clearfix job-bx wht-shd-bx")
    for job in jobs:
      date_posted= job.find("span", class_="sim-posted").text.strip()
      if "few" in date_posted: #custmize for recently
        compnany_name= job.find("h3" ,class_="joblist-comp-name").text.replace(" ","").strip()
        skill = job.find("span",class_="srp-skills").text.replace(" ","").strip()
        jd = job.header.h2.a['href']
        print(f'''
    company Name : {compnany_name}
    Skills Needed: {skill}
    Apply Link   : {jd}
    date posted  : {date_posted}
    ''')
if __name__=="__main__":
  while True:
   scrap_jobs()
   print("waiting for five Seconds")
   time.sleep(5)
# Out:
# please provide your skill sets in comma separated way java
#
#     company Name : AMARTECHNOLABSPVTLTD
# (MoreJobs)
#     Skills Needed: php,asp.net,meansstack,frontend,python,DigitalMarketing,BusinessDevelopment,webdeveloper,phpprogrammer,juniorprogrammer
#     Apply Link   : https://www.timesjobs.com/job-detail/internship-opportunity-for-software-developer-bca-diploma-be-excel-ptp-solutions-ahmedabad-0-to-1-yrs-jobid-VWLx7DZn6S9zpSvf__PLUS__uAgZw==&source=srp
#     date posted  : Posted few days ago
#
#
#     company Name : IDZDigital
#     Skills Needed: mobile,ios,SoftwareDeveloper
#     Apply Link   : https://www.timesjobs.com/job-detail/software-developer-idz-digital-mumbai-0-to-3-yrs-jobid-CuzZ7qwLdINzpSvf__PLUS__uAgZw==&source=srp
#     date posted  : Posted few days ago
#
#
#     company Name : CylsysSoftwareSolutionsPvt.Ltd.
#     Skills Needed: html5,mobile,softwaredeveloper
# ...

# %% [markdown]
# Thanks You
